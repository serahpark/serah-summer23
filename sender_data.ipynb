# %%
import pandas as pd

# %%
df = pd.read_csv('~/../data/princeton_emails/corpus_v1.0.csv')
# Out:
# /tmp/ipykernel_763006/4226839694.py:1: DtypeWarning: Columns (5,6,7,8,12,13,14,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('~/../data/princeton_emails/corpus_v1.0.csv')

# %%
# checking for entries with empty party affiliations
# from original paper, candidates were found from ballotpedia while PACs were found from opensecrets
df.loc[df['type'].isna()]
# Out:
#                                from_name                         from_address  \
# 0                      Kathleen Williams          info@kathleenformontana.com
# 1       Goal Update -- via Team Kathleen          info@kathleenformontana.com
# 2                      Kathleen Williams          info@kathleenformontana.com
# 3                      Kathleen Williams  teamwilliams@kathleenformontana.com
# 4                             Jeff Allen  teamwilliams@kathleenformontana.com
# ...                                  ...                                  ...
# 317361                      Lisa Pavlock                  lisafor93@gmail.com
# 317362              Anibal Valdez-Ortega    valdezortegaforcongress@gmail.com
# 317363                      Dan McEntire                  dan@danmcentire.com
# 317364                      Matt Cargile            mcargile@bri4colorado.com
# 317365      matt@mattreevesforsenate.com         matt@mattreevesforsenate.com
#
# ...

# %%
# sampled 1k emails with empty party affiliations
pd.set_option('display.max_rows', 1000)
pd.read_csv('corpus_sample/no_party_sample.csv')
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0      156717
# 1               1      156813
# 2               2      156909
# 3               3      157005
# 4               4      157101
# 5               5      157197
# 6               6      157293
# 7               7      157389
# 8               8      157485
# 9               9      157581
# 10             10      157677
# 11             11      157773
# 12             12      157869
# 13             13      157965
# 14             14      158061
# 15             15      158157
# 16             16      158253
# 17             17      158349
# 18             18      158445
# 19             19      158541
# 20             20      158637
# 21             21      158733
# 22             22      158829
# 23             23      158925
# 24             24      159021
# 25             25      159117
# 26             26      159213
# 27             27      159309
# 28             28      159405
# 29             29      159501
# ...

# %%
# filtering by type could be helpful since PACs are identified while those marked NaN are likely candidates
df.groupby(['from_address'], dropna=False).count()
# Out:
#                                                     from_name  subject  \
# from_address
# 144thsecretary@gmail.com                                    1        1
# 2020@christinpowers.com                                     1        1
# 2020@constancelavjohnson.com                                1        1
# 2020@culpforgovernor.com                                    4        4
# 2020@donate-2020.com                                        8        8
# ...                                                       ...      ...
# zeke@bowmanforcongress.com                                  2        2
# zmeunier@ritahart.com                                       1        1
# zmich2020@gmail.com                                         1        1
# zw29rlhupneu@a2plcpnl0863.prod.iad2.secureserve...          2        2
# NaN                                                         5        7
#
#                                                     body_text  name  \
# from_address
# ...

# %%
addresses
# Out:
# Index([                            '144thsecretary@gmail.com',
#                                     '2020@christinpowers.com',
#                                '2020@constancelavjohnson.com',
#                                    '2020@culpforgovernor.com',
#                                        '2020@donate-2020.com',
#                                        '2020@jimhagedorn.net',
#                                           '2020@rightgop.com',
#                                     '2020@thedailygrind.news',
#                                  '2020a1a@thedailygrind.news',
#                                   '2020alert@donate-2020.com',
#        ...
#                                           'zac@zacroeill.com',
#                                          'zach@zachmoses.com',
#                                         'zachmoses@gmail.com',
#                                         'zack@zacktaylor.org',
#                                     'zane.petersen@gmail.com',
# ...

# %%
# Joe Collins was a candidate for a TX House seat but office_sought, party_affiliation, etc all NaN
df.loc[df['office_sought'].isna()]
# Out:
#                            from_name                            from_address  \
# 156622                   Joe Collins          info@joecollinsforcongress.org
# 156623                   Joe Collins          info@joecollinsforcongress.org
# 156624                   Joe Collins          info@joecollinsforcongress.org
# 156625                   Joe Collins          info@joecollinsforcongress.org
# 156626        Ted H. (Chairman, CDP)  info@committeetodefendthepresident.com
# ...                              ...                                     ...
# 317215      Kara, Team Assembly Dems              info@assemblydemocrats.com
# 317216                Join us at 7PM              info@assemblydemocrats.com
# 317217            Assembly Democrats              info@assemblydemocrats.com
# 317218  Dianne Hesselbein (personal)              info@assemblydemocrats.com
# 317219               big news @ ADCC              info@assemblydemocrats.com
#
# ...

# %%
# discrepancies in from_name, body_text vs office_sought, party_affiliation - missing values for these fields?
df.groupby(['from_address'], dropna=False).count().sort_values('body_text', ascending=False).head(50)
# Out:
#                                  from_name  subject  body_text   name  \
# from_address
# admin@endcitizensunited.org          13292    13292      13292  13292
# info@dscc.org                        13114    13114      13114  13114
# admin@turnoutpac.org                  9078     9078       9078   9078
# info@traindemocrats.org               8026     8026       8026   8026
# admin@boldpac.com                     7414     7414       7414   7414
# info@bradypac.org                     7226     7226       7226   7226
# admin@stop-republicans.org            6857     6857       6857   6857
# info@cbcpac.org                       6485     6485       6485   6485
# info@joebiden.com                     5983     5983       5983   5983
# info@mjfortexas.com                   4760     4760       4760   4760
# info@wendydavisforcongress.com        4674     4674       4674   4674
# info@weareprogressives.org            4148     4148       4148   4148
# ...

# %%
df.groupby(['name', 'date'], dropna=False).count().sort_values('body_text', ascending=False).head(50)
# Out:
#                                                  from_name  from_address  \
# name                                 date
# Congressional Progressive Caucus PAC 2020-09-30        152           152
#                                      2020-09-29        140           140
# Sima Ladjevardian                    2020-09-30        133           133
# Congressional Progressive Caucus PAC 2020-10-02        132           132
# Medicare for All PAC                 2020-09-30        131           131
# Congressional Progressive Caucus PAC 2020-10-05        130           130
#                                      2020-10-04        129           129
#                                      2020-10-01        127           127
# Democratic Conservation Alliance     2020-09-30        127           127
# Congressional Progressive Caucus PAC 2020-09-28        126           126
#                                      2020-09-19        126           126
# ...

# %%
# looking at all emails from one sender on the same date - some that are corresponding to candidates (ex. Desiree Tims
# are correctly labeled under office_sought, etc. while PACs have empty fields & labeled as PACs under type
df.loc[(df['from_address'] == 'admin@endcitizensunited.org') & (df['date'] == '2020-10-14')]
# Out:
#                                                 from_name  \
# 17113                 our jaws are on the floor (via ECU)
# 17117                  YES YES YES - McConnell BLINDSIDED
# 17367   These Senators + You = Democratic Senate Majority
# 17388          600%-Match: South Carolina Campaign Update
# 17402        Trump BLINDSIDED [Texas Voter Contact - ECU]
# 17433               600%-Match Activated - Ruin McConnell
# 17503                                        Nancy Pelosi
# 17528                                           Farewell!
# 17714                                nothing left to say.
# 17888            Thank the USPS [via End Citizens United]
# 17955        𝗗𝗘𝗦𝗧𝗥𝗢𝗬 Lindsey Graham ❗(600%-Match via ECU)
# 17965                              we were SO wrong [ECU]
# 17996                                            Goodbye!
# 18007                           Please read, don’t delete
# 18418                          HORRIBLE HORRIBLE HORRIBLE
# ...

# %%
# 2 emails with different subjects but similar body_texts (likely for A/B testing)
print(df.at[17433, 'body_text'])
# Out:
# End Citizens United is dedicated to electing Democrats, transforming our broken campaign finance system, and ultimately ending Citizens United. If you really want to receive only our most urgent emails or unsubscribe, click here.
# Alex -- Click here to make a 600%-MATCHED donation to DESTROY Mitch McConnell >>
# Alex:  Mitch McConnell will do ANYTHING to confirm a 3rd Trump Justice -- and after he manipulated Mitt Romney, he has all the votes he needs to do it!
# Alex:  BUT an amazing poll says McConnell is SINKING - we can beat him [!]
# McConnell 40 - McGrath 41
# Alex:  So we’re shifting money to our Defeat McConnell fund to CRUSH him in 3 SHORT WEEKS. We have TV ads on NBC, ABC and CBS to end his Majority!
# WE’RE BEGGING YOU: we need $52,000 to Destroy Mitch McConnell and his Senate majority by Friday at noon. Can you give $5? (we’ll match it 600%)
# 600%-MATCH: $5 ➞
# 600%-MATCH: $25 ➞
# 600%-MATCH: $50 ➞
# 600%-MATCH: $100 ➞
# 600%-MATCH: $250 ➞
# 600%-MATCH:
# ...

# %%
print(df.at[17402, 'body_text'])
# Out:
# End Citizens United is dedicated to electing Democrats, transforming our broken campaign finance system, and ultimately ending Citizens United. If you really want to receive only our most urgent emails or unsubscribe, click here.
# TODAY ONLY: WE’LL 600%-MATCH YOUR DONATION. So give $5 RIGHT NOW to Contact Texas Voters and BEAT Donald Trump. Here’s Why:
# ONE: Joe Biden and Donald Trump are VIRTUALLY TIED in Texas.
# TWO: Beto O’Rourke has been hustling ALL YEAR to register over 100,000 new voters. Texas is PRIMED to turn BLUE!
# THREE: But Alex, our Voter Contact Program is expensive.
# We only need $75,120 more to hit our Texas Budget goal and SWEEP the state. So please, stop what you’re doing and give everything you can afford [it’ll be worth it!] →
# 600%-MATCH: $5 >>
# 600%-MATCH: $25 >>
# 600%-MATCH: $50 >>
# 600%-MATCH: $100 >>
# 600%-MATCH: $250 >>
# 600%-MATCH:
# Custom Amount >>
# ...
