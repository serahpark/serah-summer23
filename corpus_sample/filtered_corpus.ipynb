# %%
import pandas as pd

# %%
df = pd.read_csv('filtered_corpus.csv', index_col=0).reset_index(drop=True)

# %%
df
# Out:
#                                from_name                         from_address  \
# 0                      Kathleen Williams          info@kathleenformontana.com
# 1       Goal Update -- via Team Kathleen          info@kathleenformontana.com
# 2                      Kathleen Williams          info@kathleenformontana.com
# 3                      Kathleen Williams  teamwilliams@kathleenformontana.com
# 4                             Jeff Allen  teamwilliams@kathleenformontana.com
# ...                                  ...                                  ...
# 121169                      Lisa Pavlock                  lisafor93@gmail.com
# 121170              Anibal Valdez-Ortega    valdezortegaforcongress@gmail.com
# 121171                      Dan McEntire                  dan@danmcentire.com
# 121172                      Matt Cargile            mcargile@bri4colorado.com
# 121173      matt@mattreevesforsenate.com         matt@mattreevesforsenate.com
#
# ...

# %%
df.groupby(['from_address'], dropna=False).count().sort_values('from_name', ascending=True).head(50)
# Out:
#                                          from_name  subject  body_text  name  \
# from_address
# 144thsecretary@gmail.com                         1        1          1     1
# joshforny@gmail.com                              1        1          1     1
# josh@shannaforpa.org                             1        1          1     1
# josh@petecowden.com                              1        1          1     1
# josh@people4utah.org                             1        1          1     1
# josh@joshstein.org                               1        1          1     1
# josh@joshfornd.com                               1        1          1     1
# josephson4rep@gmail.com                          1        1          1     1
# josephgiannino@gmail.com                         1        1          1     1
# joseph@saraforkansas.com                         1        1          1     1
# joseph.simpson@thehomeslicegroup.com             1        1          1     1
# ...

# %%
# Willis was a U.S. Taxpayers Party of Michigan candidate, Knezevich was an independent candidate
df.loc[df['party_affiliation'] == "None"]
# Out:
#                     from_name             from_address  \
# 112853  WILLISFORCONGRESS.COM  exedirector34@gmail.com
# 112854  WILLISFORCONGRESS.COM  exedirector34@gmail.com
# 117909      Michael Knezevich   msk@mskforcongress.com
#
#                                    subject  \
# 112853  Click to confirm your subscription
# 112854  Click to confirm your subscription
# 117909                             Thanks:
#
#                                                 body_text  \
# 112853  To activate your subscription, please follow t...
# 112854  To activate your subscription, please follow t...
# 117909  I have until June 7th to raise 7K to get my na...
#
#                             name                   office_sought  \
# 112853            Valerie Willis            U.S. Senate Michigan
# 112854            Valerie Willis            U.S. Senate Michigan
# 117909  Michael Steven Knezevich  U.S. House Florida District 12
#
#        party_affiliation office_level district_type  \
# ...

# %%
# Elliott Scheirman was a libertarian candidate
df.loc[df['party_affiliation'].isna()]
# Out:
#                              from_name                    from_address  \
# 121128  Elliott Scheirman for Congress  scheirmanforcongress@gmail.com
# 121129  Elliott Scheirman for Congress  scheirmanforcongress@gmail.com
# 121130  Elliott Scheirman for Congress  scheirmanforcongress@gmail.com
# 121131  Elliott Scheirman for Congress  scheirmanforcongress@gmail.com
#
#                                                   subject  \
# 121128  Fwd: Volunteer Call For Scheirman For Congress...
# 121129           Scheirman For Congress Volunteer Message
# 121130  Volunteer Call For Scheirman For Congress Star...
# 121131  Volunteer Call For Scheirman For Congress Star...
#
#                                                 body_text               name  \
# 121128  Donors and Volunteers,\nHere's a recap video f...  Elliott Scheirman
# 121129  Thank you so much for supporting the campaign!...  Elliott Scheirman
# 121130  Donors and Volunteers,\nThank you for your con...  Elliott Scheirman
# ...

# %%
independents.at[626, 'body_text']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 independents.at[626, 'body_text']
#
# NameError: name 'independents' is not defined
