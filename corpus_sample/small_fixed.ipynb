# %%
import pandas as pd

# %%
pd.read_csv('~/serah-summer23/small_fixed.csv')
# Out:
#                                             from_name  \
# 0                                   Kathleen Williams
# 1                    Goal Update -- via Team Kathleen
# 2                                   Kathleen Williams
# 3                                   Kathleen Williams
# 4                                          Jeff Allen
# 5                                       Team Kathleen
# 6                                          Montana HQ
# 7                                   Kathleen Williams
# 8                                      Blake Thompson
# 9                                          Montana HQ
# 10                                  Kathleen Williams
# 11                                         Jeff Allen
# 12                                      Team Kathleen
# 13                                      Team Kathleen
# 14                                     Blake Thompson
# 15                                      Team Kathleen
# ...

# %%
df = pd.read_csv('small_fixed.csv')
grouped_by_sender = df.groupby("from_name")
for name, group in grouped_by_sender:
    print(name)
# Out:
# Blake Thompson
# Campaign Update -- via Team Kathleen
# Cora Neumann
# Goal Update -- via Team Kathleen
# Jeff Allen
# Jon Tester
# Kathleen HQ
# Kathleen Williams
# Montana HQ
# Public Lands -- via Team Kathleen
# Public Lands Petition -- via Team Williams
# Rapid Response Needed -- via Team Kathleen
# Ratings Change via Kathleen Williams for Congress
# Team Kathleen
# Team Williams

# %%
grouped_by_sender.nunique()
# Out:
#                                                    from_address  subject  \
# from_name
# Blake Thompson                                                1        6
# Campaign Update -- via Team Kathleen                          1        2
# Cora Neumann                                                  1        1
# Goal Update -- via Team Kathleen                              1        1
# Jeff Allen                                                    1        5
# Jon Tester                                                    1        1
# Kathleen HQ                                                   1        1
# Kathleen Williams                                             2       14
# Montana HQ                                                    1        4
# Public Lands -- via Team Kathleen                             1        1
# Public Lands Petition -- via Team Williams                    1        1
# Rapid Response Needed -- via Team Kathleen                    1        1
# ...

# %%
grouped_by_sender["from_name"].value_counts()
# Out:
# from_name
# Blake Thompson                                        6
# Campaign Update -- via Team Kathleen                  2
# Cora Neumann                                          1
# Goal Update -- via Team Kathleen                      1
# Jeff Allen                                            5
# Jon Tester                                            1
# Kathleen HQ                                           1
# Kathleen Williams                                    15
# Montana HQ                                            4
# Public Lands -- via Team Kathleen                     1
# Public Lands Petition -- via Team Williams            1
# Rapid Response Needed -- via Team Kathleen            1
# Ratings Change via Kathleen Williams for Congress     1
# Team Kathleen                                         8
# Team Williams                                         1
# Name: count, dtype: int64
