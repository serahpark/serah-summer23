# %%
import pandas as pd

# %%
black_house_candidates = pd.read_csv('../2020_black_house_candidates.csv')

# %%
black_house_candidates
# Out:
#           candidate_name  party           office_sought  %_votes
# 0         James Averhart      D               Alabama 1   35.50%
# 1    Phyllis Harvey-Hall      D               Alabama 2   34.70%
# 2           Adia Winfrey      D               Alabama 3   32.50%
# 3           Terri Sewell      D               Alabama 7   97.20%
# 4         William Hanson      D              Arkansas 4   27.50%
# ..                   ...    ...                     ...      ...
# 119            Mike Espy      D      Mississippi Senate   44.10%
# 120      Raphael Warnock      D          Georgia Senate   51.00%
# 121       Jaime Harrison      D   South Carolina Senate   44.20%
# 122    Marquita Bradshaw      D        Tennessee Senate   35.20%
# 123           John James      R         Michigan Senate   48.20%
#
# [124 rows x 4 columns]
