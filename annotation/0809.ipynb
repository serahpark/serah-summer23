# %%
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
agreement = pd.read_csv('../annotator_agreement.csv', index_col=0)

# %%
agreement.loc[(agreement['agreementA'] == False) | (agreement['agreementB'] == False) | (agreement['agreementC'] == False)]
# Out:
#                                             body_text  \
# 0   Your Power is Growing! Don't Stop Now!\n####\n...
# 1   You don't want to miss this.\nSecuring the Bor...
# 14  Alex,\nMy opponent just became the first candi...
# 21  As violence continues in our streets, Virginia...
# 26  Friend,\nOur Chairman Nick Langworthy is in Ch...
# 30  Hi Alex,\nFirst, I want to remind you that Our...
# 42  Fellow conservative,\nFor weeks, we have seen ...
# 44  This mob frenzy has metastasized into a cancer...
# 60  Sign your name and show the state of Kansas we...
# 94  Help take back VA-10!  View this email in your...
#
#                            uid_email  annotator1A  annotator1B  annotator1C  \
# 0   5b7d6ebef9442b5f19e01db1a7de4fbd          1.0          1.0          0.0
# 1   e1df1228075e229ab349c95800350158          0.0          0.0          0.0
# 14  373d814ca63b2f31a93a4fa88e67e50d          0.0          1.0          0.0
# ...

# %%
agreement
# Out:
#                                             body_text  \
# 0   Your Power is Growing! Don't Stop Now!\n####\n...
# 1   You don't want to miss this.\nSecuring the Bor...
# 2   For months, Donald Trump downplayed the risk o...
# 3   Are you and I "pro-crime?" Let me explain what...
# 4   ░░░░░ ██░░░░░░░ ██░░░░░░░░░ ██░░░░░░░░░ ██░░░░...
# 5   it's time for him to answer for his actions.\n...
# 6   President Trump needs you.\nTrump Pence Keep A...
# 7   With only weeks until Election Day, we need to...
# 8   We can elect candidates who are more than just...
# 9   You are invited to our upcoming Laguna Beach M...
# 10  The candidates will make their pitches for how...
# 11  Alex,\nLast week the MNGOP, the House Republic...
# 12  the future of the Senate and the Supreme Court...
# 13  Our July 4th celebrations are taking on a very...
# 14  Alex,\nMy opponent just became the first candi...
# 15  URGENT: Give $5 to defeat McConnell before our...
# ...
