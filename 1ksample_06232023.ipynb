# %%
import pandas as pd
import spacy
import pickle
from time import time
from spacy.language import Language

nlp = spacy.load("en_core_web_sm")
nlp.add_pipe("merge_noun_chunks")
nlp.add_pipe("merge_entities")
nlp.Defaults.stop_words |= {"alex", "unsubscribe"}

# @Language.component("remove_stopwords")
# def remove_stopwords(doc):
#     # This will remove stopwords and punctuation.
#     # Use token.text to return strings, which we'll need for Gensim.
#     doc = [token.text for token in doc if token.is_stop != True and token.is_punct != True]
#     return doc

#nlp.add_pipe("remove_stopwords")

# %%
preprocess_start = time()
df = pd.read_csv('corpus_sample/sample.csv')

# %%
import tqdm

body_text = df.loc[:, 'body_text']

emails = []
include_named_entities = False
print("starting spacy preprocessing pipeline")
for email in list(nlp.pipe(body_text)):
    if include_named_entities == True:
        emails.append([token.text.lower() for token in email if not token.is_stop and token.text.isalpha()])
    else:
        emails.append([token.text.lower() for token in email if not token.is_stop and token.text.isalpha() and not token.ent_type_])

# for text in body_text:
#     email = nlp(text)
#     if include_named_entities:
#         emails.append([token.lemma_.lower() for token in email if not token.is_stop and token.text.isalpha()])
#     else:
#         emails.append([token.lemma_.lower() for token in email if not token.is_stop and token.text.isalpha() and not token.ent_type_])
# Out:
# starting spacy preprocessing pipeline
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       6 include_named_entities = False
#       7 print("starting spacy preprocessing pipeline")
# ----> 8 for email in list(nlp.pipe(body_text)):
#       9     print('hi')
#      10     if include_named_entities == True:
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/language.py:1574, in Language.pipe(self, texts, as_tuples, batch_size, disable, component_cfg, n_process)
#    1572     for pipe in pipes:
#    1573         docs = pipe(docs)
# -> 1574 for doc in docs:
#    1575     yield doc
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/util.py:1680, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1678     if arg in kwargs:
#    1679         kwargs.pop(arg)
# -> 1680 for doc in docs:
#    1681     try:
#    1682         doc = proc(doc, **kwargs)  # type: ignore[call-arg]
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/util.py:1680, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1678     if arg in kwargs:
#    1679         kwargs.pop(arg)
# -> 1680 for doc in docs:
#    1681     try:
#    1682         doc = proc(doc, **kwargs)  # type: ignore[call-arg]
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/util.py:1670, in _pipe(docs, proc, name, default_error_handler, kwargs)
#    1660 def _pipe(
#    1661     docs: Iterable["Doc"],
#    1662     proc: "PipeCallable",
#    (...)
#    1667     kwargs: Mapping[str, Any],
#    1668 ) -> Iterator["Doc"]:
#    1669     if hasattr(proc, "pipe"):
# -> 1670         yield from proc.pipe(docs, **kwargs)
#    1671     else:
#    1672         # We added some args for pipe that __call__ doesn't expect.
#    1673         kwargs = dict(kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/pipeline/transition_parser.pyx:239, in pipe()
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/pipeline/transition_parser.pyx:253, in spacy.pipeline.transition_parser.Parser.predict()
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/pipeline/transition_parser.pyx:274, in spacy.pipeline.transition_parser.Parser.greedy_parse()
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:315, in Model.predict(self, X)
#     311 def predict(self, X: InT) -> OutT:
#     312     """Call the model's `forward` function with `is_train=False`, and return
#     313     only the output, instead of the `(output, callback)` tuple.
#     314     """
# --> 315     return self._func(self, X, is_train=False)[0]
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/ml/tb_framework.py:33, in forward(model, X, is_train)
#      32 def forward(model, X, is_train):
# ---> 33     step_model = ParserStepModel(
#      34         X,
#      35         model.layers,
#      36         unseen_classes=model.attrs["unseen_classes"],
#      37         train=is_train,
#      38         has_upper=model.attrs["has_upper"],
#      39     )
#      41     return step_model, step_model.finish_steps
#
# File ~/anaconda3/lib/python3.10/site-packages/spacy/ml/parser_model.pyx:213, in spacy.ml.parser_model.ParserStepModel.__init__()
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/with_array.py:43, in forward(model, Xseq, is_train)
#      41     return model.layers[0](Xseq, is_train)
#      42 else:
# ---> 43     return cast(Tuple[SeqT, Callable], _list_forward(model, Xseq, is_train))
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/with_array.py:78, in _list_forward(model, Xs, is_train)
#      76 lengths = NUMPY_OPS.asarray1i([len(seq) for seq in Xs])
#      77 Xf = layer.ops.flatten(Xs, pad=pad)
# ---> 78 Yf, get_dXf = layer(Xf, is_train)
#      80 def backprop(dYs: ListXd) -> ListXd:
#      81     dYf = layer.ops.flatten(dYs, pad=pad)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/residual.py:41, in forward(model, X, is_train)
#      38     else:
#      39         return d_output + dX
# ---> 41 Y, backprop_layer = model.layers[0](X, is_train)
#      42 if isinstance(X, list):
#      43     return [X[i] + Y[i] for i in range(len(X))], backprop
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
#     [... skipping similar frames: Model.__call__ at line 291 (1 times)]
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/chain.py:55, in forward(model, X, is_train)
#      53 callbacks = []
#      54 for layer in model.layers:
# ---> 55     Y, inc_layer_grad = layer(X, is_train=is_train)
#      56     callbacks.append(inc_layer_grad)
#      57     X = Y
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/model.py:291, in Model.__call__(self, X, is_train)
#     288 def __call__(self, X: InT, is_train: bool) -> Tuple[OutT, Callable]:
#     289     """Call the model's `forward` function, returning the output and a
#     290     callback to compute the gradients via backpropagation."""
# --> 291     return self._func(self, X, is_train=is_train)
#
# File ~/anaconda3/lib/python3.10/site-packages/thinc/layers/maxout.py:53, in forward(model, X, is_train)
#      51 W = model.get_param("W")
#      52 W = model.ops.reshape2f(W, nO * nP, nI)
# ---> 53 Y = model.ops.gemm(X, W, trans2=True)
#      54 Y += model.ops.reshape1f(b, nO * nP)
#      55 Z = model.ops.reshape3f(Y, Y.shape[0], nO, nP)
#
# KeyboardInterrupt:

# %%
# for email in list(nlp.pipe(body_text[0:3])):
#     for token in email:
#         print(token.text, token.lemma_,token.pos_)

# %%
import gensim
import gensim.corpora as corpora
# Create a dictionary representation of the documents.
dictionary = corpora.Dictionary(emails)

# Filter out words that occur less than 10 documents, or more than 50% of the documents.
dictionary.filter_extremes(no_below=10, no_above=0.5)


corpus = [dictionary.doc2bow(doc) for doc in emails]

# %%
with open("dictionary", "wb") as d:
    pickle.dump(dictionary, d)
    
with open("corpus", "wb") as c:
    pickle.dump(corpus, c)

# %%
with open("dictionary", "rb") as d:
    dictionary = pickle.load(d)
    
with open("corpus", "rb") as c:
    corpus = pickle.load(c)

# %%
preprocess_end = time()
print("Time to pre-process corpus: " + str(preprocess_end - preprocess_start))
# Out:
# Time to pre-process corpus: 267.19581604003906

# %%
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 781
# Number of documents: 1000

# %%
# Enable logging to see the progress of training
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
lda_start = time()

# %%
# Train LDA model.
from gensim.models import LdaModel

# Set training parameters.
num_topics = 30
chunksize = 10000
passes = 20
iterations = 400
eval_every = None  # Don't evaluate model perplexity, takes too much time.

# Make an index to word dictionary.
temp = dictionary[0]  # This is only to "load" the dictionary.
id2word = dictionary.id2token

model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    chunksize=chunksize,
    alpha='auto',
    eta='auto',
    iterations=iterations,
    num_topics=num_topics,
    passes=passes,
    eval_every=eval_every
)
# Out:
# 2023-06-23 11:28:47,613 : INFO : using autotuned alpha, starting with [0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335, 0.033333335]
# 2023-06-23 11:28:47,615 : INFO : using serial LDA version on this node
# 2023-06-23 11:28:47,616 : INFO : running online (multi-pass) LDA training, 30 topics, 20 passes over the supplied corpus of 1000 documents, updating model once every 1000 documents, evaluating perplexity every 0 documents, iterating 400x with a convergence threshold of 0.001000
# 2023-06-23 11:28:47,617 : INFO : PROGRESS: pass 0, at document #1000/1000
# 2023-06-23 11:28:48,157 : INFO : optimized alpha [0.028946212, 0.031154182, 0.028833129, 0.030035164, 0.029902, 0.03046672, 0.02955405, 0.031022707, 0.029518217, 0.029321525, 0.028983543, 0.030977357, 0.029816959, 0.029633114, 0.029024301, 0.029319879, 0.029244013, 0.03004275, 0.030461287, 0.029097425, 0.030505553, 0.030181602, 0.029281605, 0.029174611, 0.028755749, 0.031151945, 0.030430205, 0.029706465, 0.02963369, 0.030149369]
# 2023-06-23 11:28:48,159 : INFO : topic #24 (0.029): 0.018*"stand" + 0.018*"turn" + 0.018*"express" + 0.017*"sure" + 0.013*"click" + 0.013*"watch" + 0.013*"hate" + 0.013*"running" + 0.013*"live" + 0.013*"away"
# 2023-06-23 11:28:48,159 : INFO : topic #2 (0.029): 0.034*"mail" + 0.027*"help" + 0.023*"believe" + 0.020*"join" + 0.017*"voting" + 0.017*"turn" + 0.017*"send" + 0.017*"like" + 0.016*"voters" + 0.014*"fighting"
# 2023-06-23 11:28:48,159 : INFO : topic #7 (0.031): 0.033*"like" + 0.025*"support" + 0.022*"stay" + 0.022*"stand" + 0.021*"turn" + 0.017*"endorsed" + 0.017*"running" + 0.016*"email" + 0.016*"elected" + 0.015*"click"
# 2023-06-23 11:28:48,160 : INFO : topic #1 (0.031): 0.049*"turn" + 0.022*"dc" + 0.021*"vote" + 0.020*"yes" + 0.017*"know" + 0.017*"like" + 0.014*"tell" + 0.013*"help" + 0.012*"support" + 0.011*"right"
# 2023-06-23 11:28:48,160 : INFO : topic #25 (0.031): 0.024*"help" + 0.020*"want" + 0.020*"protect" + 0.019*"mail" + 0.019*"running" + 0.018*"send" + 0.017*"sure" + 0.014*"sent" + 0.013*"like" + 0.013*"receive"
# 2023-06-23 11:28:48,160 : INFO : topic diff=15.301386, rho=1.000000
# 2023-06-23 11:28:48,162 : INFO : PROGRESS: pass 1, at document #1000/1000
# 2023-06-23 11:28:48,398 : INFO : optimized alpha [0.027372262, 0.030609118, 0.02696393, 0.028805904, 0.029693276, 0.02938548, 0.027982036, 0.030468423, 0.027856044, 0.027461432, 0.027274612, 0.030401826, 0.028775642, 0.028501283, 0.02747897, 0.027825497, 0.027541127, 0.028923666, 0.028871842, 0.027393652, 0.029182134, 0.02900105, 0.027882224, 0.027296493, 0.026789906, 0.030076966, 0.03055794, 0.028322319, 0.02820376, 0.029298572]
: INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=781, num_topics=30, decay=0.5, chunksize=10000> in 3.57s', 'datetime': '2023-06-23T11:28:51.190802', 'gensim': '4.3.1', 'python': '3.11.1 (v3.11.1:a7a450f84a, Dec  6 2022, 15:24:06) [Clang 13.0.0 (clang-1300.0.29.30)]', 'platform': 'macOS-12.3-arm64-arm-64bit', 'event': 'created'}

# %%
lda_end = time()
print("LDA run time: " + str(lda_end - lda_start))
# Out:
# LDA run time: 3.584449052810669

# %%
top_topics = model.top_topics(corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# 2023-06-23 11:28:51,207 : INFO : CorpusAccumulator accumulated stats from 1000 documents
# Average topic coherence: -2.5144.
# [([(0.04114365, 'send'),
#    (0.033993747, 'want'),
#    (0.032094512, 'help'),
#    (0.03065659, 'running'),
#    (0.030131951, 'join'),
#    (0.029161625, 'reaching'),
#    (0.028918454, 'mt'),
#    (0.028366111, 'protect'),
#    (0.028147332, 'follow'),
#    (0.027976215, 'receive'),
#    (0.027506795, 'safe'),
#    (0.027139328, 'anymore'),
#    (0.026932793, 'fix'),
#    (0.026689371, 'works'),
#    (0.02668776, 'sent'),
#    (0.026583383, 'isolated'),
#    (0.026409546, 'feeling'),
#    (0.024876136, 'mail'),
#    (0.021185515, 'monthly'),
#    (0.01859789, 'immediately')],
#   -0.49744246556551003),
#  ([(0.059456293, 'express'),
#    (0.04289329, 'like'),
#    (0.028380226, 'running'),
#    (0.024362314, 'elected'),
#    (0.024122542, 'stand'),
#    (0.023382204, 'support'),
#    (0.022971401, 'stay'),
#    (0.022405878, 'endorsed'),
#    (0.021345077, 'date'),
#    (0.02121285, 'recenter'),
#    (0.020868726, 'email'),
#    (0.020803528, 'hate'),
#    (0.020241048, 'supporting'),
#    (0.020045849, 'click'),
#    (0.01978722, 'chip'),
#    (0.018473549, 'immediately'),
#    (0.015152798, 'saved'),
#    (0.014677362, 'help'),
#    (0.01273557, 'know'),
#    (0.012351603, 'win')],
#   -0.6812213910232585),
#  ([(0.081162944, 'sure'),
#    (0.048666805, 'send'),
#    (0.04813869, 'running'),
#    (0.038807794, 'sent'),
#    (0.03789717, 'receive'),
#    (0.037836645, 'anymore'),
#    (0.036057547, 'right'),
#    (0.03568135, 'want'),
#    (0.03541308, 'fix'),
#    (0.033026617, 'mail'),
#    (0.032412317, 'protect'),
#    (0.030780574, 'help'),
#    (0.029953338, 'early'),
#    (0.029933449, 'check'),
#    (0.027572146, 'immediately'),
#    (0.0272805, 'saved'),
#    (0.02504226, 'vote'),
#    (0.023376625, 'hit'),
#    (0.020571264, 'chip'),
#    (0.020353278, 'raise')],
#   -0.9679012973506465),
#  ([(0.043821957, 'support'),
#    (0.038951743, 'like'),
#    (0.03299114, 'stand'),
#    (0.032419946, 'stay'),
#    (0.03141186, 'endorsed'),
#    (0.028897438, 'email'),
#    (0.027614623, 'click'),
#    (0.027052715, 'elected'),
#    (0.026613796, 'date'),
#    (0.026596699, 'running'),
#    (0.026407514, 'hate'),
#    (0.024822552, 'recenter'),
#    (0.02395401, 'supporting'),
#    (0.014707719, 'friend'),
#    (0.011121592, 'sure'),
#    (0.011113566, 'help'),
#    (0.01026359, 'sign'),
#    (0.010073558, 'know'),
#    (0.009447984, 'right'),
#    (0.009127485, 'join')],
#   -0.9897559315882799),
#  ([(0.0348655, 'send'),
#    (0.02484938, 'want'),
#    (0.02366965, 'like'),
#    (0.021569688, 'chip'),
#    (0.019590149, 'help'),
#    (0.018115437, 'let'),
#    (0.017201634, 'fix'),
#    (0.016412528, 'sent'),
#    (0.016396537, 'protect'),
#    (0.014958315, 'anymore'),
#    (0.014555165, 'saved'),
#    (0.014491946, 'mail'),
#    (0.014415296, 'receive'),
#    (0.014245886, 'fight'),
#    (0.014045561, 'immediately'),
#    (0.013906657, 'join'),
#    (0.012420242, 'know'),
#    (0.012235873, 'announced'),
#    (0.012165282, 'running'),
#    (0.011591143, 'shows')],
#   -1.2522108822488704),
#  ([(0.045750074, 'protect'),
#    (0.025721312, 'mail'),
#    (0.021746088, 'add'),
#    (0.020066159, 'want'),
#    (0.017995324, 'protecting'),
#    (0.016962321, 'ready'),
#    (0.016863998, 'clear'),
#    (0.016370088, 'running'),
#    (0.013604756, 'sent'),
#    (0.0126697095, 'away'),
#    (0.0125013925, 'join'),
#    (0.011633203, 'let'),
#    (0.011270762, 'safe'),
#    (0.011119588, 'support'),
#    (0.0111070275, 'receive'),
#    (0.010986715, 'looking'),
#    (0.010761302, 'send'),
#    (0.010682224, 'help'),
#    (0.009941318, 'stand'),
#    (0.009737972, 'voting')],
#   -1.2797162899066166),
#  ([(0.068293355, 'vote'),
#    (0.06045434, 'home'),
#    (0.0552281, 'turn'),
#    (0.053729564, 'win'),
#    (0.037838917, 'stay'),
#    (0.03670265, 'plan'),
#    (0.03338535, 'update'),
#    (0.029482448, 'risk'),
#    (0.026755968, 'dc'),
#    (0.025829459, 'reach'),
#    (0.024071278, 'seen'),
#    (0.023771537, 'voting'),
#    (0.022094455, 'trying'),
#    (0.021596463, 'seriously'),
#    (0.020801423, 'craft'),
#    (0.018700548, 'failed'),
#    (0.01760519, 'stayed'),
#    (0.016500967, 'die'),
#    (0.014935118, 'continues'),
#    (0.014701996, 'quick')],
#   -1.6173547331137228),
#  ([(0.06667964, 'president'),
#    (0.04172228, 'jo'),
#    (0.039144408, 'help'),
#    (0.031144595, 'liberty'),
#    (0.03045878, 'raise'),
#    (0.027176967, 'stand'),
#    (0.026896149, 'counting'),
#    (0.023381356, 'fighting'),
#    (0.020533146, 'reach'),
#    (0.016709175, 'click'),
#    (0.016509276, 'fund'),
#    (0.014309229, 'consider'),
#    (0.013951297, 'voters'),
#    (0.0136161195, 'let'),
#    (0.012035877, 'end'),
#    (0.011874088, 'send'),
#    (0.011412871, 'support'),
#    (0.009894124, 'earn'),
#    (0.008792337, 'ensure'),
#    (0.008717386, 'asking')],
#   -1.6295434715509989),
#  ([(0.058367208, 'turn'),
#    (0.03571602, 'expand'),
#    (0.03442365, 'win'),
#    (0.034137037, 'control'),
#    (0.031028204, 'right'),
#    (0.022991663, 'support'),
#    (0.021918641, 'voters'),
#    (0.019960953, 'putting'),
#    (0.018745929, 'protect'),
#    (0.018388715, 'beat'),
#    (0.017374882, 'access'),
#    (0.015390376, 'roll'),
#    (0.01517643, 'short'),
#    (0.015006677, 'dc'),
#    (0.0139054805, 'wo'),
#    (0.013566798, 'home'),
#    (0.013238723, 'falling'),
#    (0.012950411, 'winning'),
#    (0.012838117, 'stayed'),
#    (0.012518826, 'stop')],
#   -1.7392403702616743),
#  ([(0.04206064, 'president'),
#    (0.036715277, 'bring'),
#    (0.030824166, 'voters'),
#    (0.028272193, 'help'),
#    (0.019777834, 'home'),
#    (0.01794538, 'clicking'),
#    (0.017508095, 'select'),
#    (0.01725084, 'time'),
#    (0.016594887, 'let'),
#    (0.015992645, 'hear'),
#    (0.015712254, 'available'),
#    (0.015642641, 'ending'),
#    (0.013840609, 'plan'),
#    (0.013149386, 'clear'),
#    (0.013134464, 'want'),
#    (0.013002766, 'join'),
#    (0.012856828, 'come'),
#    (0.012096278, 'happen'),
#    (0.0120218415, 'stay'),
#    (0.011802338, 'end')],
#   -1.8023953459853481),
#  ([(0.09356989, 'turn'),
#    (0.034039676, 'dc'),
#    (0.022935765, 'yes'),
#    (0.022781393, 'know'),
#    (0.01933721, 'vote'),
#    (0.01660857, 'wo'),
#    (0.013393041, 'voters'),
#    (0.013032393, 'steal'),
#    (0.012994597, 'protect'),
#    (0.012092164, 'tell'),
#    (0.0115267625, 'come'),
#    (0.010994478, 'expand'),
#    (0.010809692, 'use'),
#    (0.010698044, 'save'),
#    (0.009789693, 'like'),
#    (0.009758248, 'seen'),
#    (0.009429921, 'stand'),
#    (0.00913789, 'right'),
#    (0.008829195, 'voting'),
#    (0.008567072, 'defend')],
#   -1.8756904895597304),
#  ([(0.037295546, 'help'),
#    (0.02715164, 'people'),
#    (0.024019454, 'find'),
#    (0.02389433, 'want'),
#    (0.02341342, 'join'),
#    (0.02101123, 'volunteers'),
#    (0.02052136, 'sure'),
#    (0.019501628, 'president'),
#    (0.019287959, 'reach'),
#    (0.01713039, 'let'),
#    (0.015675846, 'important'),
#    (0.014636512, 'know'),
#    (0.014096036, 'voters'),
#    (0.013894733, 'like'),
#    (0.013828179, 'sign'),
#    (0.012530991, 'volunteer'),
#    (0.012177019, 'send'),
#    (0.011343386, 'events'),
#    (0.01107811, 'contact'),
#    (0.010239119, 'joining')],
#   -1.9860201974450462),
#  ([(0.02991249, 'help'),
#    (0.02558069, 'people'),
#    (0.023253364, 'redacted'),
#    (0.022674099, 'url'),
#    (0.016703872, 'fight'),
#    (0.016365265, 'like'),
#    (0.016285066, 'want'),
#    (0.015573044, 'liberty'),
#    (0.01453313, 'president'),
#    (0.014041019, 'love'),
#    (0.012924992, 'share'),
#    (0.012653318, 'join'),
#    (0.012182688, 'know'),
#    (0.012104053, 'better'),
#    (0.011793156, 'find'),
#    (0.011017757, 'hope'),
#    (0.010836629, 'care'),
#    (0.010597267, 'feel'),
#    (0.01016534, 'best'),
#    (0.009686096, 'stop')],
#   -2.0587496459521706),
#  ([(0.045845427, 'help'),
#    (0.032349806, 'send'),
#    (0.025036307, 'quarter'),
#    (0.022477755, 'want'),
#    (0.021826493, 'running'),
#    (0.02043264, 'right'),
#    (0.019977614, 'end'),
#    (0.019281244, 'authorized'),
#    (0.017456777, 'stand'),
#    (0.017009316, 'let'),
#    (0.016920444, 'possible'),
#    (0.016013108, 'president'),
#    (0.015398613, 'protect'),
#    (0.015029565, 'add'),
#    (0.0146774305, 'mt'),
#    (0.014639846, 'sending'),
#    (0.014603234, 'fundraising'),
#    (0.013677319, 'fill'),
#    (0.013268049, 'report'),
#    (0.012861234, 'sent')],
#   -2.106289059247987),
#  ([(0.07529753, 'turn'),
#    (0.03231717, 'dc'),
#    (0.030083027, 'yes'),
#    (0.027373983, 'according'),
#    (0.023488035, 'support'),
#    (0.022355823, 'know'),
#    (0.019232675, 'agree'),
#    (0.018107837, 'working'),
#    (0.016388688, 'tell'),
#    (0.014199291, 'cast'),
#    (0.012512648, 'sure'),
#    (0.012416039, 'fight'),
#    (0.011629134, 'let'),
#    (0.011063722, 'providing'),
#    (0.010372054, 'protect'),
#    (0.010080977, 'like'),
#    (0.009515889, 'vote'),
#    (0.009309977, 'win'),
#    (0.009093644, 'provide'),
#    (0.0090158405, 'ready')],
#   -2.1212383784759745),
#  ([(0.05966422, 'reach'),
#    (0.040108316, 'president'),
#    (0.03492719, 'voters'),
#    (0.032503568, 'want'),
#    (0.026356608, 'help'),
#    (0.025411831, 'send'),
#    (0.023926865, 'click'),
#    (0.022773456, 'like'),
#    (0.016354874, 'hope'),
#    (0.013878907, 'received'),
#    (0.012931291, 'directly'),
#    (0.012768022, 'know'),
#    (0.012751319, 'liberty'),
#    (0.012727403, 'reaching'),
#    (0.012097834, 'raise'),
#    (0.011489699, 'possible'),
#    (0.0107556265, 'online'),
#    (0.010429006, 'order'),
#    (0.009659108, 'donated'),
#    (0.009352761, 'personally')],
#   -2.2016518174453297),
#  ([(0.09205405, 'turn'),
#    (0.04755289, 'yes'),
#    (0.045434374, 'dc'),
#    (0.030805562, 'tell'),
#    (0.022359744, 'vote'),
#    (0.020240217, 'know'),
#    (0.020225814, 'like'),
#    (0.017772663, 'said'),
#    (0.017162114, 'beat'),
#    (0.016770536, 'help'),
#    (0.016750619, 'taking'),
#    (0.016041353, 'means'),
#    (0.015561196, 'saying'),
#    (0.015343822, 'answer'),
#    (0.0145390015, 'retake'),
#    (0.014280318, 'support'),
#    (0.014076523, 'craft'),
#    (0.012669952, 'approve'),
#    (0.011297761, 'think'),
#    (0.010409076, 'answering')],
#   -2.216279854377082),
#  ([(0.05406056, 'add'),
#    (0.034777217, 'sign'),
#    (0.016207738, 'needs'),
#    (0.015835423, 'running'),
#    (0.014694962, 'continue'),
#    (0.01421836, 'protect'),
#    (0.013038913, 'thanks'),
#    (0.012985641, 'stand'),
#    (0.012263729, 'send'),
#    (0.012106271, 'demand'),
#    (0.011520344, 'address'),
#    (0.011385204, 'let'),
#    (0.011329393, 'want'),
#    (0.010612049, 'tell'),
#    (0.010483166, 'committed'),
#    (0.010389617, 'like'),
#    (0.010271988, 'instead'),
#    (0.010229938, 'fix'),
#    (0.010057121, 'raising'),
#    (0.009967719, 'facing')],
#   -2.294134172593127),
#  ([(0.03285471, 'people'),
#    (0.0309751, 'believe'),
#    (0.027760068, 'president'),
#    (0.02357032, 'let'),
#    (0.023463212, 'want'),
#    (0.02301146, 'continue'),
#    (0.020376598, 'consider'),
#    (0.018007055, 'change'),
#    (0.017586818, 'coming'),
#    (0.016215065, 'voters'),
#    (0.015768522, 'join'),
#    (0.014507037, 'share'),
#    (0.01437772, 'spread'),
#    (0.01335849, 'voting'),
#    (0.012777755, 'best'),
#    (0.012537173, 'longer'),
#    (0.011935665, 'wish'),
#    (0.011356111, 'run'),
#    (0.011326541, 'liberty'),
#    (0.011282034, 'making')],
#   -2.52568871511256),
#  ([(0.09037219, 'turn'),
#    (0.046146207, 'dc'),
#    (0.04419141, 'yes'),
#    (0.026060428, 'approve'),
#    (0.024121102, 'know'),
#    (0.023149448, 'stand'),
#    (0.020996988, 'answering'),
#    (0.020562978, 'saying'),
#    (0.017105808, 'tell'),
#    (0.015958495, 'think'),
#    (0.014856112, 'agree'),
#    (0.013875443, 'want'),
#    (0.01369661, 'according'),
#    (0.013183785, 'found'),
#    (0.012784973, 'wo'),
#    (0.012469822, 'children'),
#    (0.011800277, 'calling'),
#    (0.01155432, 'trying'),
#    (0.011002816, 'said'),
#    (0.010517922, 'going')],
#   -2.6807846361050527),
#  ([(0.027689753, 'people'),
#    (0.025298106, 'read'),
#    (0.023020092, 'president'),
#    (0.022700472, 'think'),
#    (0.021144383, 'destroying'),
#    (0.021025682, 'stand'),
#    (0.019187134, 'secure'),
#    (0.019017475, 'win'),
#    (0.018788151, 'use'),
#    (0.017001774, 'turn'),
#    (0.014908498, 'mail'),
#    (0.014686036, 'click'),
#    (0.014535392, 'better'),
#    (0.013642271, 'let'),
#    (0.012887616, 'know'),
#    (0.012772385, 'voted'),
#    (0.012667972, 'help'),
#    (0.012256959, 'advance'),
#    (0.011835362, 'laws'),
#    (0.011568177, 'want')],
#   -2.754385425289119),
#  ([(0.08000877, 'turn'),
#    (0.03489179, 'like'),
#    (0.032801885, 'means'),
#    (0.028664285, 'know'),
#    (0.024663143, 'dc'),
#    (0.02454237, 'giving'),
#    (0.023400072, 'believe'),
#    (0.017305683, 'cast'),
#    (0.017151285, 'yes'),
#    (0.017097294, 'help'),
#    (0.016275518, 'win'),
#    (0.014790597, 'mail'),
#    (0.014697399, 'vote'),
#    (0.01282825, 'forever'),
#    (0.012710257, 'counted'),
#    (0.011944039, 'victory'),
#    (0.01035308, 'having'),
#    (0.010296906, 'ballots'),
#    (0.009964635, 'going'),
#    (0.0096088415, 'won')],
#   -2.8475319164444453),
#  ([(0.037934814, 'help'),
#    (0.026634568, 'away'),
#    (0.024216278, 'let'),
#    (0.019653318, 'sure'),
#    (0.018963074, 'politicians'),
#    (0.018739134, 'stop'),
#    (0.01738365, 'sent'),
#    (0.016709603, 'change'),
#    (0.016310396, 'fight'),
#    (0.015416562, 'want'),
#    (0.015074857, 'click'),
#    (0.013785139, 'work'),
#    (0.013034595, 'leaders'),
#    (0.011973619, 'president'),
#    (0.011890935, 'software'),
#    (0.011555254, 'come'),
#    (0.0114722615, 'receiving'),
#    (0.010264386, 'emails'),
#    (0.008842949, 'neck'),
#    (0.008794708, 'live')],
#   -3.2674623118970825),
#  ([(0.039791614, 'send'),
#    (0.038485877, 'president'),
#    (0.026693765, 'let'),
#    (0.023638451, 'voters'),
#    (0.021859355, 'want'),
#    (0.01699505, 'know'),
#    (0.014937795, 'miss'),
#    (0.014772675, 'supports'),
#    (0.014660424, 'going'),
#    (0.01438338, 'respond'),
#    (0.013933748, 'raise'),
#    (0.013048834, 'continue'),
#    (0.013026538, 'facebook'),
#    (0.013014731, 'learn'),
#    (0.012392206, 'honored'),
#    (0.0123409545, 'click'),
#    (0.012170252, 'following'),
#    (0.011210223, 'support'),
#    (0.010515725, 'require'),
#    (0.010413565, 'ending')],
#   -3.482707558522587),
#  ([(0.073174365, 'reach'),
#    (0.065547235, 'voters'),
#    (0.0588931, 'president'),
#    (0.040655445, 'help'),
#    (0.02527295, 'liberty'),
#    (0.019745069, 'raise'),
#    (0.018385356, 'want'),
#    (0.017693216, 'provide'),
#    (0.016105913, 'click'),
#    (0.015623529, 'count'),
#    (0.014137544, 'build'),
#    (0.012943465, 'know'),
#    (0.012703231, 'comes'),
#    (0.012011091, 'team'),
#    (0.011529197, 'send'),
#    (0.011104463, 'peace'),
#    (0.01088976, 'answer'),
#    (0.01063271, 'bringing'),
#    (0.010015197, 'mean'),
#    (0.009948789, 'counted')],
#   -3.527029732745887),
#  ([(0.09991907, 'turn'),
#    (0.0441128, 'vote'),
#    (0.04029494, 'dc'),
#    (0.02858072, 'know'),
#    (0.0274992, 'support'),
#    (0.026043033, 'like'),
#    (0.019880543, 'voting'),
#    (0.019479921, 'mail'),
#    (0.019009992, 'yes'),
#    (0.01881196, 'win'),
#    (0.017668389, 'answering'),
#    (0.0133570675, 'tell'),
#    (0.012456861, 'voters'),
#    (0.011872305, 'vp'),
#    (0.008742181, 'stand'),
#    (0.008692307, 'won'),
#    (0.008677128, 'power'),
#    (0.008321716, 'according'),
#    (0.007829122, 'home'),
#    (0.007770839, 'flip')],
#   -3.697293028779322),
#  ([(0.06706803, 'mail'),
#    (0.06175194, 'voting'),
#    (0.06018421, 'excited'),
#    (0.035117462, 'believe'),
#    (0.030738728, 'hit'),
#    (0.022133218, 'click'),
#    (0.020963298, 'turn'),
#    (0.02079645, 'probably'),
#    (0.0201809, 'spread'),
#    (0.020039078, 'set'),
#    (0.01882853, 'believes'),
#    (0.018739443, 'puts'),
#    (0.01774293, 'join'),
#    (0.01742837, 'stand'),
#    (0.01653946, 'makes'),
#    (0.01620439, 'head'),
#    (0.015395871, 'right'),
#    (0.015194691, 'risk'),
#    (0.015134751, 'fighting'),
#    (0.01427001, 'rely')],
#   -3.6985380369352265),
#  ([(0.07532795, 'vote'),
#    (0.050040133, 'mail'),
#    (0.028069116, 'win'),
#    (0.027718889, 'voting'),
#    (0.022382483, 'like'),
#    (0.02067352, 'add'),
#    (0.019324407, 'quickly'),
#    (0.01868044, 'fight'),
#    (0.014281838, 'continues'),
#    (0.013543763, 'running'),
#    (0.013019495, 'looks'),
#    (0.011605607, 'making'),
#    (0.011188271, 'money'),
#    (0.009936739, 'good'),
#    (0.009850399, 'look'),
#    (0.009824941, 'commit'),
#    (0.009620867, 'week'),
#    (0.009395995, 'spread'),
#    (0.009337145, 'act'),
#    (0.00928234, 'polling')],
#   -5.06835669472742),
#  ([(0.06572979, 'color'),
#    (0.056804776, 'violence'),
#    (0.045225814, 'starts'),
#    (0.042647146, 'passed'),
#    (0.041054413, 'allow'),
#    (0.036585968, 'turn'),
#    (0.03196885, 'telling'),
#    (0.021239525, 'simply'),
#    (0.020831445, 'breaking'),
#    (0.020417579, 'threatening'),
#    (0.01910656, 'join'),
#    (0.018392282, 'election'),
#    (0.018117258, 'away'),
#    (0.018078994, 'dc'),
#    (0.017174218, 'reports'),
#    (0.015390383, 'happen'),
#    (0.015149642, 'watch'),
#    (0.015076172, 'win'),
#    (0.014792094, 'tell'),
#    (0.014705291, 'counter')],
#   -5.526295360648239),
#  ([(0.028680516, 'help'),
#    (0.025970701, 'maybe'),
#    (0.023066249, 'let'),
#    (0.021798437, 'president'),
#    (0.021006742, 'trust'),
#    (0.020099243, 'spreading'),
#    (0.018497389, 'despite'),
#    (0.018339206, 'know'),
#    (0.018028283, 'try'),
#    (0.015478355, 'straight'),
#    (0.014924479, 'moved'),
#    (0.014313446, 'lies'),
#    (0.013565411, 'watch'),
#    (0.012247075, 'reach'),
#    (0.012243541, 'expanding'),
#    (0.011962718, 'life'),
#    (0.011479447, 'spread'),
#    (0.011434858, 'finally'),
#    (0.011152708, 'committed'),
#    (0.010967554, 'pandemic')],
#   -7.040222678052815)]

# %%
# dist = []
# for topic in lda_output:
#     topic_sum = 0
#     for word in topic:
#         topic_sum += word[0]
#     dist.append(topic_sum)

# normalizer = sum(dist)
    
# normalized = []
# for topic_dist in dist:
#     normalized_topic = topic_dist / normalizer
#     normalized.append(normalized_topic)
    
# print(dist)

# %%
# import matplotlib.pyplot as plt

# # Create a list of indices for the x-axis
# x = range(num_topics)
# x_labels = ['Topic 1', 'Topic 2', 'Topic 3', 'Topic 4', 'Topic 5', 'Topic 6', 'Topic 7', 'Topic 8', 'Topic 9', 'Topic 10']

# # Plotting the bar graph
# plt.bar(x, normalized, tick_label=x_labels)

# # Add labels and title
# plt.xlabel('Topics')
# plt.ylabel('Probability')
# plt.title('Topic Probability Distribution')

# # Display the plot
# plt.show()
