# %% [markdown]
# # Calculating PMI

# %% [markdown]
# For a given target word t="crime", and all other co-occurring words w (dictionary), need to compute:
#
# P(t) = (total # of emails w/ "crime" tokens)/(total # of emails in corpus)
# - len of crime subset / len of corpus
#
# P(w) = (total # of emails w/ w tokens)/(total # of emails in corpus)
# - keyword search for w in full corpus -> len of w subset / len of corpus
#
# P(t, w) = (# of emails with "crime" and w in the same email)/(total # of emails in entire corpus)
# - keyword search for w in crime subset -> keep count or len of t,w subset / len of corpus

# %%
import pandas as pd
# pd.set_option('display.max_rows', None)
# import yaml
import pickle
import math

# %% [markdown]
# ## Primary candidates PMI

# %%
primary_candidates_corpus = pd.read_csv('../corpus_sample/primary_candidates_corpus.csv')

# %%
# leprimary_candidates_corpusus
primary_corpus_length = len(primary_candidates_corpus)

# %%
primary_crime_subset = pd.read_csv('../corpus_sample/primary_candidates_crime_subset.csv')

# %%
# calculating P(t)
primary_p_t = len(primary_crime_subset) / len(primary_candidates_corpus)
primary_p_t
# Out:
# 0.008154201352375469

# %%
pmi = pd.read_csv('pmi_primary.csv', index_col=0)

# %%
pmi = pmi.loc[pmi['p_w'] > 0]

# %%
import numpy as np

# %%
pmi['p(tw)/p(t)p(w)'] = pmi['p_tw'] / (pmi['p_w'] * primary_p_t)

# %%
pd.set_option('display.float_format', lambda x: '%0.5f' % x)

# %%
pmi['pmi'] = np.log(pmi['p(tw)/p(t)p(w)'])

# %%
sort = pmi.sort_values('pmi', ascending = False)

# %%
sort.head(50)

# %%
sort = sort.rename(columns={'p_w': 'p(w)', 'p_tw': 'p(t,w)', 'p(tw)/p(t)p(w)': 'p(t,w)/p(t)p(w)'})
sort.loc[~sort['w'].str.contains('crime')].head(10)

# %% [markdown]
# # Primary candidates PMI (original case)

# %%
# generate list of w
with open('../pickle/primary_candidates_crime_tokens_original_case', 'rb') as c:
    original_case_crime_tokens = pickle.load(c)

# word_count maps tokens with their frequencies in crime subset
original_case_w_count = {}

for email in original_case_crime_tokens:
    for word in email:
        original_case_w_count[word] = 1 + original_case_w_count.get(word, 0)

# %%
# initialize PMI dataframe with w's
w_list = [w for w in original_case_w_count if original_case_w_count[w] > 20]
original_case_pmi = pd.DataFrame(w_list, columns=['w'])

# %%
original_case_pmi

# %%
original_case_pmi['corpus_w_count'] = original_case_pmi['w'].apply(count_keyword_primary)

# %%
original_case_pmi['p(w)'] = original_case_pmi['corpus_w_count'] / primary_corpus_length

# %%
original_case_pmi['p(t,w)'] = original_case_pmi['w'].apply(calculate_cooccurrence_primary)

# %%
original_case_pmi.to_csv('new_pmi.csv')

# %%
new_pmi = pd.read_csv('pmi_calculations.csv', index_col=0)

# %%
new_pmi
# Out:
#                      w  corpus_w_count      p(w)  p(t,w)
# 0                 hear           27544  0.161815     269
# 1                 soon            6815  0.040037      54
# 2                asked            5014  0.029456      56
# 3            Democrats           61219  0.359648     581
# 4                stand           45426  0.266868     621
# ...                ...             ...       ...     ...
# 1943       Sandy Smith             107  0.000629      13
# 1944       Butterfield             109  0.000640      13
# 1945  G.K. Butterfield              93  0.000546      13
# 1946      Doug Collins              92  0.000540      17
# 1947    Kelly Loeffler             731  0.004294      25
#
# [1948 rows x 4 columns]

# %%
new_pmi['p(t,w)/p(t)p(w)'] = new_pmi['p(t,w)'] / ((new_pmi['p(w)'] * primary_p_t))

# %%
pd.set_option('display.float_format', lambda x: '%0.5f' % x)

# %%
new_pmi['pmi'] = np.log(new_pmi['p(t,w)/p(t)p(w)'])
# Out:
# /home/serah/anaconda3/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
new_pmi = new_pmi.sort_values('pmi', ascending=False).loc[new_pmi['corpus_w_count'] > 20]

# %%
new_pmi = new_pmi.head(100)

# %%
new_pmi
# Out:
#                                   w  corpus_w_count    p(w)  p(t,w)  \
# 1468                        “Unsure              37 0.00022      37
# 1185                     war crimes              36 0.00021      36
# 1474  an urgent public opinion poll              33 0.00019      33
# 1873                the fine values              32 0.00019      32
# 1874   our President Donald J Trump              32 0.00019      32
# ...                             ...             ...     ...     ...
# 1301                    Roger Stone             163 0.00096      45
# 1075                        abusing             227 0.00133      62
# 1136                        looters             122 0.00072      33
# 1903            Joe's campaign chip             167 0.00098      44
# 1902  radical leftist Maxine Waters             170 0.00100      44
#
#       p(t,w)/p(t)p(w)      pmi
# 1468   20875005.73560 16.85406
# 1185   20875005.73560 16.85406
# 1474   20875005.73560 16.85406
# 1873   20875005.73560 16.85406
# 1874   20875005.73560 16.85406
# ...               ...      ...
# 1301    5763038.39326 15.56698
# 1075    5701543.41677 15.55625
# 1136    5646517.94487 15.54655
# 1903    5500001.51117 15.52026
# 1902    5402942.66098 15.50245
#
# [100 rows x 6 columns]

# %% [markdown]
# # Keyword analysis to find out unique # of senders

# %%
def unique_senders(w):
    senders = set()
    for index, row in primary_candidates_corpus.iterrows():
        if w in str(row['body_text']):
            senders.add(row['name'])
    return len(senders)

# %%
new_pmi['unique_senders'] = new_pmi['w'].apply(unique_senders)
filtered_pmi = new_pmi.loc[new_pmi['unique_senders'] > 1]
# Out:
# /tmp/ipykernel_2328992/3137842116.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_pmi['unique_senders'] = new_pmi['w'].apply(unique_senders)

# %%
def list_senders(w):
    senders = set()
    for index, row in primary_candidates_corpus.iterrows():
        if w in str(row['body_text']):
            senders.add(row['name'])
    return senders
# Out:
#                                   w  corpus_w_count    p(w)  p(t,w)  \
# 1468                        “Unsure              37 0.00022      37
# 1185                     war crimes              36 0.00021      36
# 1474  an urgent public opinion poll              33 0.00019      33
# 829                    their crimes              30 0.00018      30
# 1072                 Trump’s crimes              30 0.00018      30
# ...                             ...             ...     ...     ...
# 1301                    Roger Stone             163 0.00096      45
# 1075                        abusing             227 0.00133      62
# 1136                        looters             122 0.00072      33
# 1903            Joe's campaign chip             167 0.00098      44
# 1902  radical leftist Maxine Waters             170 0.00100      44
#
#       p(t,w)/p(t)p(w)      pmi  unique_senders
# 1468   20875005.73560 16.85406               7
# 1185   20875005.73560 16.85406              11
# 1474   20875005.73560 16.85406               7
# 829    20875005.73560 16.85406              20
# 1072   20875005.73560 16.85406              17
# ...               ...      ...             ...
# 1301    5763038.39326 15.56698              60
# 1075    5701543.41677 15.55625              92
# 1136    5646517.94487 15.54655              41
# 1903    5500001.51117 15.52026               2
# 1902    5402942.66098 15.50245               2
#
# [78 rows x 7 columns]

# %%
filtered_pmi['senders'] = filtered_pmi['w'].apply(list_senders)
# Out:
# /tmp/ipykernel_2328992/335700549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_pmi['senders'] = filtered_pmi['w'].apply(list_senders)

# %%
filtered_pmi.loc[~filtered_pmi['w'].str.contains('crime')].head(50)
# Out:
#                                                w  corpus_w_count    p(w)  \
# 1468                                     “Unsure              37 0.00022
# 1474               an urgent public opinion poll              33 0.00019
# 1462  her administration’s Department of Justice              27 0.00016
# 1137                              ANTIFA members              21 0.00012
# 1138                         our nation’s cities              21 0.00012
# 1142                          our border control              21 0.00012
# 1144               our great nation’s principles              21 0.00012
# 1553                                misdemeanors              21 0.00012
# 1824             my Complete & Total Endorsement              41 0.00024
# 1864                                -Nikki Haley              38 0.00022
# 1472                     criminal investigations              38 0.00022
# 1865                             what a blessing              32 0.00019
# 1866                      a great [[URL REDACTED              32 0.00019
# 1863                              a good quality              39 0.00023
# 1860                    the next couple of years              28 0.00016
# 1832                                      A Part              31 0.00018
# 1844                             the Trump train              28 0.00016
# 1823                                    our Vets              45 0.00026
# 1822                                       Loves              47 0.00028
# 1837                     -President Donald Trump              46 0.00027
# 1851                                    TERRIFIC              25 0.00015
# 1867                              the Ambassador              38 0.00022
# 1835                                     HAGERTY              50 0.00029
# 1812                                    Straight              54 0.00032
# 1127                                our Military              67 0.00039
# 1461                                   NO CHOICE              37 0.00022
# 1831                                       ## Be              55 0.00032
# 1842                          Tennessee families              32 0.00019
# 1905                                  JOE DEFEAT              28 0.00016
# 1397                              people's right              36 0.00021
# 1838                                advantageous              39 0.00023
# 1730                                     invaded              23 0.00014
# 393                                     lynching              92 0.00054
# 1463                            criminal charges              51 0.00030
# 1398                                 your lawyer              40 0.00023
# 1757                         a monumental impact              25 0.00015
# 1800                                     CHARGED              27 0.00016
# 1816                                      Saying              80 0.00047
# 1406                                   his taxes              44 0.00026
# 1872                        this campaign season              64 0.00038
# 1850                                     Beijing              56 0.00033
# 1651                                       \--He              23 0.00014
# 1906                                      MAXINE              55 0.00032
# 1848                               a good friend              49 0.00029
# 1134                 our second amendment rights              54 0.00032
# 1586                           violent criminals              56 0.00033
# 1652                his Supreme Court nomination              42 0.00025
# 614                                   prosecuted              58 0.00034
# 1243                                   the abuse              90 0.00053
# 1820                                       Japan             121 0.00071
#
#       p(t,w)  p(t,w)/p(t)p(w)      pmi  unique_senders  \
# 1468      37   20875005.73560 16.85406               7
# 1474      33   20875005.73560 16.85406               7
# 1462      27   20875005.73560 16.85406               7
# 1137      21   20875005.73559 16.85406               3
# 1138      21   20875005.73559 16.85406               3
# 1142      21   20875005.73559 16.85406               3
# 1144      21   20875005.73559 16.85406               3
# 1553      21   20875005.73559 16.85406              18
# 1824      40   20365859.25424 16.82937               2
# 1864      37   20325663.47939 16.82739               2
# 1472      37   20325663.47939 16.82739               8
# 1865      31   20222661.80636 16.82231               2
# 1866      31   20222661.80636 16.82231               2
# 1863      37   19804492.62095 16.80142               3
# 1860      26   19383933.89734 16.77996               3
# 1832      28   18854843.89022 16.75228               3
# 1844      25   18638397.97821 16.74073               3
# 1823      40   18555560.65386 16.73628               4
# 1822      41   18210111.38637 16.71749               8
# 1837      40   18152178.90052 16.71430               4
# 1851      21   17535004.81790 16.67971               5
# 1867      31   17029609.94219 16.65046               5
# 1835      40   16700004.58848 16.63092               4
# 1812      42   16236115.57213 16.60275              14
# 1127      52   16201496.98882 16.60061              14
# 1398  {Marie Newman, Sima Ladjevardian, Brynne Kenne...
# 1757  {Bryan Berghoef, Marie Newman, Marquita Bradsh...
# 1800  {Sima Ladjevardian, Marie Newman, Brynne Kenne...
# 1816  {Candace Valenzuela, Julie Oliver, John Cornyn...
# 1406  {Desiree Tims, Mark Warner, Sean Maloney, TJ C...
# 1872  {Salud Carbajal, John Hickenlooper, Andom Gheb...
# 1850  {John James, Steve Chabot, Scherie Murray, Mar...
# 1651  {Marie Newman, Sima Ladjevardian, Phil Arballo...
# 1906     {Scherie Murray, Alek Skarlatos, Debbie Lesko}
# 1848  {Adair Ford Boroughs, Tina Smith, Abby Broyles...
# 1134  {Joshua Scott, Alek Skarlatos, Guy Reschenthal...
# 1586  {John Cummings, Alek Skarlatos, Andy Caldwell,...
# 1652  {John Hickenlooper, Gary Peters, Alek Skarlato...
# 614   {Ed Markey, John Cummings, Alek Skarlatos, Hal...
# 1243  {David Young, Ken Calvert, Ihssane Leckey, Jul...
# 1820  {Ben Sasse, Rishi Kumar, Alek Skarlatos, Josep...

# %%
def count_email_addresses(w):
    senders = set()
    for index, row in primary_candidates_corpus.iterrows():
        if w in str(row['body_text']):
            senders.add(row['from_address'])
    return len(senders)

# %%
filtered_pmi['unique_emails'] = filtered_pmi['w'].apply(count_email_addresses)
# Out:
# /tmp/ipykernel_2328992/1303921981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_pmi['unique_emails'] = filtered_pmi['w'].apply(count_email_addresses)

# %%
filtered_pmi.loc[~filtered_pmi['w'].str.contains('crime')].head(50)
# Out:
#                                                w  corpus_w_count    p(w)  \
# 1468                                     “Unsure              37 0.00022
# 1474               an urgent public opinion poll              33 0.00019
# 1462  her administration’s Department of Justice              27 0.00016
# 1137                              ANTIFA members              21 0.00012
# 1138                         our nation’s cities              21 0.00012
# 1142                          our border control              21 0.00012
# 1144               our great nation’s principles              21 0.00012
# 1553                                misdemeanors              21 0.00012
# 1824             my Complete & Total Endorsement              41 0.00024
# 1864                                -Nikki Haley              38 0.00022
# 1472                     criminal investigations              38 0.00022
# 1865                             what a blessing              32 0.00019
# 1866                      a great [[URL REDACTED              32 0.00019
# 1863                              a good quality              39 0.00023
# 1860                    the next couple of years              28 0.00016
# 1832                                      A Part              31 0.00018
# 1844                             the Trump train              28 0.00016
# 1823                                    our Vets              45 0.00026
# 1822                                       Loves              47 0.00028
# 1837                     -President Donald Trump              46 0.00027
# 1851                                    TERRIFIC              25 0.00015
# 1867                              the Ambassador              38 0.00022
# 1835                                     HAGERTY              50 0.00029
# 1812                                    Straight              54 0.00032
# 1127                                our Military              67 0.00039
# 1461                                   NO CHOICE              37 0.00022
# 1831                                       ## Be              55 0.00032
# 1842                          Tennessee families              32 0.00019
# 1905                                  JOE DEFEAT              28 0.00016
# 1397                              people's right              36 0.00021
# 1838                                advantageous              39 0.00023
# 1730                                     invaded              23 0.00014
# 393                                     lynching              92 0.00054
# 1463                            criminal charges              51 0.00030
# 1398                                 your lawyer              40 0.00023
# 1757                         a monumental impact              25 0.00015
# 1800                                     CHARGED              27 0.00016
# 1816                                      Saying              80 0.00047
# 1406                                   his taxes              44 0.00026
# 1872                        this campaign season              64 0.00038
# 1850                                     Beijing              56 0.00033
# 1651                                       \--He              23 0.00014
# 1865                   {Elizabeth Matory, Bill Hagerty}              2
# 1866                     {Bill Hagerty, Kathaleen Wall}              2
# 1863  {Jamaal Bowman, Bill Hagerty, Christopher Armi...              3
# 1860               {Rick Laib, Bill Hagerty, Andy Barr}              3
# 1832         {Teddy Daniels, Bill Hagerty, John Cornyn}              3
# 1844        {Donald Trump, Bill Hagerty, James Mackler}              3
# 1823  {Bill Hagerty, Russ Fulcher, Anthony Brindisi,...              4
# 1822  {Lynne Homrich, Leon Benjamin, Harley Rouda, H...              7
# 1837  {Daniel Rodimer, Alek Skarlatos, Bill Hagerty,...              6
# 1851  {Candace Valenzuela, Nabilah Islam, Lulu Seika...              3
# 1867  {Young Kim, Manny Sethi, Donna Deegan, Donald ...              6
# 1835  {Mitch McConnell, James Mackler, Bill Hagerty,...              4
# 1812  {Claudia Tenney, Nicole Malliotakis, Kathleen ...             13
# 1127  {Daniel Merritt, Susan Wild, Chris Pappas, Kev...             14
# 1461  {Marie Newman, Sima Ladjevardian, Brynne Kenne...             11
# 1831  {Steve Chabot, Michael Bloomberg, Lisa Welch, ...              8
# 1842  {James Mackler, Bill Hagerty, Christopher Hale...              4
# 1905                     {Debbie Lesko, Alek Skarlatos}              9
# 1397  {Dana Balter, Marie Newman, Sima Ladjevardian,...             12
# 1838  {Kathy Ellis, Amanda Stuck, Quinn Nystrom, Dan...             12
# 1730  {Lorena Garcia, Albert Lee, Marie Newman, Sima...             11
# 393   {Cory Booker, Isaac McCorkle, Tina Smith, Lind...             42
# 1463  {Josh Hicks, Monika Johnson-Hostler, Desiree T...             20
# 1398  {Marie Newman, Sima Ladjevardian, Brynne Kenne...              6
# 1757  {Bryan Berghoef, Marie Newman, Marquita Bradsh...              5
# 1800  {Sima Ladjevardian, Marie Newman, Brynne Kenne...              1
# 1816  {Candace Valenzuela, Julie Oliver, John Cornyn...             21
# 1406  {Desiree Tims, Mark Warner, Sean Maloney, TJ C...             16
# 1872  {Salud Carbajal, John Hickenlooper, Andom Gheb...             24
# 1850  {John James, Steve Chabot, Scherie Murray, Mar...             18
# 1651  {Marie Newman, Sima Ladjevardian, Phil Arballo...              4
# 1906     {Scherie Murray, Alek Skarlatos, Debbie Lesko}             10
# 1848  {Adair Ford Boroughs, Tina Smith, Abby Broyles...             24
# 1134  {Joshua Scott, Alek Skarlatos, Guy Reschenthal...             28
# 1586  {John Cummings, Alek Skarlatos, Andy Caldwell,...             30
# 1652  {John Hickenlooper, Gary Peters, Alek Skarlato...             16
# 614   {Ed Markey, John Cummings, Alek Skarlatos, Hal...             38
# 1243  {David Young, Ken Calvert, Ihssane Leckey, Jul...             32
# 1820  {Ben Sasse, Rishi Kumar, Alek Skarlatos, Josep...             35

# %%
filtered_pmi.at[1553, 'senders']
# Out:
# {'Antonio Delgado',
#  'Christina Finello',
#  'Earl Blumenauer',
#  'Jason Smith',
#  'Joe Biden',
#  'Joe Walsh',
#  'John Cornyn',
#  'Lee Zeldin',
#  'Lindsey Boylan',
#  'Lindsey Graham',
#  'Lisa Scheller',
#  'Mary Jennings "M.J." Hegar',
#  'Mike Quigley',
#  'Ritchie Torres',
#  'Sara Jacobs',
#  'Tom Cotton',
#  'Wendy Davis',
#  'William Weld'}
