# %% [markdown]
# # Data

# %% [markdown]
# * 316769 emails in the dataset after removing emails with empty bodytext
# * dataset includes other information such as party affiliation, office, etc

# %%
import pandas as pd
pd.read_csv('corpus_sample/20lines.csv', index_col=0)
# Out:
#                                             from_name  \
# 0                                       Newt Gingrich
# 1                                BREAKING SCOTUS NEWS
# 2                                     Nicole Galloway
# 3              ↘↘↘ 450%-MATCH: End Trump’s Presidency
# 4                                        Steve Daines
# 5                        ⚫𝑨𝑾𝑭𝑼𝑳 Update via Team Ammar
# 6                                          Eric Trump
# 7                                         Matt Matern
# 8   💔 this CNN poll BROKE our hearts!! (via ElectD...
# 9                                      Sean McCaffity
# 10                                     Lindsey Graham
# 11                                   Outraged Patriot
# 12                                DC Democratic Party
# 13                                   no time to waste
# 14                            2020 Debate Focus Group
# 15                                 Sign the Pledge >>
# ...

# %% [markdown]
# # Topic Modeling

# %% [markdown]
# * working on fine-tuning text preprocessing steps such as including/excluding named entities (proper nouns)
# * the most recent iteration of topic modeling generated 100 topics; the authors of the original paper generated 70 topics and condensed them into 6 larger categories
# * examples of topics include: abortion rights/access, police brutality & racial justice, specific state politics, covid policies & reopening schools - [Topic Modeling Output](https://docs.google.com/document/d/15o9dLtp-QofZ_AA6IsII1TVRieRyfZ2s9o_4tbjnQII/edit?usp=sharing)

# %% [markdown]
# # Exploring Data

# %% [markdown]
# * potential extensions of topic modeling:
#     - looking at the frequency/distribution & source of specific topics such as certain social issues (all lumped under "Political Issues" in original paper); parties' policy agendas, comparative politics between local and federal level, factors that influence voting habits (that these emails exploit)
#     - sentiment analysis of certain topics (ex. how different parties/senders feel about covid policies)
#     - sources of misinformation about political issues, candidates, etc
